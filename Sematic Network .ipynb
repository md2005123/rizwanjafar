# %% [markdown]
# Our  dear friend Mark who lives in california plays soccer in a club named spinoff. Since he is new to california and he loves pets, he bought a cat. mark is a student who studies in california state university

# %%
pip install networkx
# Out:
# Requirement already satisfied: networkx in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (1.26.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from matplotlib) (6.1.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.17.0)
# Requirement already satisfied: six>=1.5 in c:\users\sys72\documents\anacod\envs\sriram\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # STATEMENT

# %%
#Mark is a student in california state university(csu)
#mark has a cat
#mark play as soccer
#mark love is animal

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
import networkx as nx

# %%
graph_mark=nx.DiGraph(info="mark's details")

# %% [markdown]
# # Create Nodes along with positions

# %%
graph_mark.add_node("Mark",pos=(0,0))
graph_mark.add_node("Cat",pos=(-2,6))
graph_mark.add_node("Student",pos=(2,-5))
graph_mark.add_node("Animal",pos=(1,6))
graph_mark.add_node("California",pos=(4,6))
graph_mark.add_node("Spinoff",pos=(-5,-5))
graph_mark.add_node("Soccer",pos=(-5,2))
graph_mark.add_node("Sports club",pos=(0,-8))
graph_mark.add_node("Csu",pos=(5,-1))
pos=nx.get_node_attributes(graph_mark,"pos")

# %% [markdown]
# # Create Edges with weights Relationships

# %%
graph_mark.add_edge("Mark","cat",weight="has a")
graph_mark.add_edge("Mark","student",weight="is a")
graph_mark.add_edge("cat","animal",weight="is a")
graph_mark.add_edge("Mark","soccer",weight="plays")
graph_mark.add_edge("Mark","spinoff",weight="is a part of")
graph_mark.add_edge("Mark","california",weight="lives in")
graph_mark.add_edge("Mark","animal",weight="loves")
graph_mark.add_edge("Student","csu",weight="in")
graph_mark.add_edge("Spinoff","sports club",weight="is a")
graph_mark.add_edge("Csu","california",weight="is in")
weight=nx.get_edge_attributes(graph_mark,"weight")

# %% [markdown]
# #PLOT THE GRAPH

# %%
plt.figure()
nx.draw_networkx(graph_mark,pos,font_weight = "bold",node_size=2000,font_size=7)
nx.draw_networkx_edge_labels(graph_mark,pos,edge_lable+weight)
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 3
#       1 plt.figure()
#       2 nx.draw_networkx(graph_mark,pos,font_weight = "bold",node_size=2000,font_size=7)
# ----> 3 nx.draw_networkx_edge_labels(graph_mark,pos,edge_lable+weight)
#
# NameError: name 'edge_lable' is not defined
